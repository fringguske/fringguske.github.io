# %%
from skimage import io
import matplotlib.pyplot as plt
img = io.imread("/kaggle/input/my-power-bi-report/Ekran Alnts.PNG")
plt.figure(dpi=400)
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
img = io.imread("/kaggle/input/my-power-bi-report/Ekran Alnts2.PNG")
plt.figure(dpi=400)
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
img = io.imread("/kaggle/input/my-power-bi-report/Ekran Alnts3.PNG")
plt.figure(dpi=400)
plt.imshow(img)
plt.axis('off')
plt.show()
